# %%
import cv2 
import numpy as np
import os
from matplotlib import pyplot as plt
#from func_hair import smplextract_hair
from PIL import Image
from sklearn.metrics import jaccard_score
from skimage.feature import graycomatrix, graycoprops
import pyfeats
from pathlib import Path
import math
from numpy import asarray

pathFolder_train='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/train/' 
train_Array = [x for x in os.listdir(pathFolder_train) if os.path.isfile(os.path.join(pathFolder_train,x))]
pathFolder_test='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/test/' 
test_Array = [x for x in os.listdir(pathFolder_test) if os.path.isfile(os.path.join(pathFolder_test,x))]
pathFolder_GTtrain='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/GT_train/'
GTtrain_Array = [x for x in os.listdir(pathFolder_GTtrain) if os.path.isfile(os.path.join(pathFolder_GTtrain,x))]
outputFolder_path="D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/Seg_train"
pathFolder_whHair_train="D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/whHair_train/"
pathFolder_masks_train="D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/seg_res_train/"
pathFolder_gtres_train="D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/gt_res_train/"
pathFolderdosmil="D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Training_dosmil/"
dosmilArray=[x for x in os.listdir(pathFolderdosmil) if os.path.isfile(os.path.join(pathFolderdosmil,x))]

# %%
avch1 = 0
sdevch1=0
avch2 = 0
sdevch2=0
avch3 = 0
sdevch3=0
avgt1=0
stdt1=0
avgt2=0
stdt2=0
avgt3=0
stdt3=0
avgfin1=0
stdfin1=0
avgfin2=0
stdfin2=0
avgfin3=0
stdfin3=0
for i in range(len(dosmilArray)): 
    img_o=cv2.imread(pathFolderdosmil+dosmilArray[i])
    print(img_o.shape)
    ch1, ch2, ch3 = cv2.split(img_o)  # split on 3 different channels
    print("aftersplit",ch1.shape)
    #print(type(img_o))
    #img = np.array(img_o)
    print (dosmilArray[i])
    avch1=np.mean(ch1)
    sdevch1=np.std(ch1)
    avch2 =np.mean(ch2)
    sdevch2=np.std(ch2)
    avch3 =np.mean(ch3)
    sdevch3=np.std(ch3)
    print(np.max(ch1))
    print(np.max(ch2))
    print(np.max(ch3))
    avgt1=avgt1+avch1
    stdt1=stdt1+sdevch1
    avgt2=avgt2+avch2
    stdt2=stdt2+sdevch2
    avgt3=avgt3+avch3
    stdt3=stdt3+sdevch3

    print("avg1",avch1)
    print("sdev1",sdevch1)
    print("avg2",avch2)
    print("sdev2",sdevch2)
    print("avg3",avch3)
    print("sdev3",sdevch3)

print("Final avg1",avch1)
print("Final std1",sdevch1)
print("Final avg2",avch2)
print("Final std2",sdevch2)
print("Final avg3",avch3)
print("final sdev3",sdevch3)

avgfin1=avgt1/2000
stdfin1=stdt1/2000

avgfin2=avgt2/2000
stdfin2=stdt2/2000

avgfin3=avgt3/2000
stdfin3=stdt3/2000

print("Final avg1",avgfin1)
print("Final std1",stdfin1)
print("Final avg2",avgfin2)
print("Final std2",stdfin2)
print("Final avg3",avgfin3)
print("final sdev3",stdfin3)
