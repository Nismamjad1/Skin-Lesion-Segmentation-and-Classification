# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
import shutil
import os

labels_csv=pd.read_csv("D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/ISIC-2017_Training_Data/all_diagnoses.csv")
benign=[]
#Adding 2 columns to the original csv to know which is benigng and to have the final labels.
for idx in range( len(labels_csv)):
    if labels_csv['melanoma'][idx]==0 and labels_csv['seborrheic_keratosis'][idx]==0:
        benign.append(1)
    else:
        benign.append(0)
labels_csv['benign']=benign

# labels: 0 benign, 1 melanoma,2 keratosis
final_labels=[]
for idx in range( len(labels_csv)):
    if labels_csv['benign'][idx]==1:
        final_labels.append(0)
    elif labels_csv['melanoma'][idx]==1:
        final_labels.append(1)
    else:
        final_labels.append(2)

#Exporting to a csv file
labels_csv['final_labels']=final_labels
#labels_csv.to_csv("D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/Python_codes/final_labels.csv",index=False)

#Performing the stratified k-fold to split in a class-wise form the 50% of the data
##
# X=labels_csv[['image_id']].to_numpy()
# y=labels_csv[['final_labels']].to_numpy()

# skf = StratifiedKFold(n_splits=2)
# skf.get_n_splits(X, y)

# for train_index, test_index in skf.split(X, y):
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

#Copying images to the corresponding folder (training and test)
# imgs_path='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/ISIC-2017_Training_Data/'
# for idx in range(len(X_test)):
#     img=X_test[idx][0]
#     im=imgs_path+img+'.jpg'
#     print(im)
#     shutil.copy(im,'D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/test')

# pathFolder_test='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/test/' 
# filesArray = [x for x in os.listdir(pathFolder_test) if os.path.isfile(os.path.join(pathFolder_test,x))]

# for img in filesArray:
#     print(img)

##FOR GroundTruth
# X=labels_csv[['image_id']].to_numpy()
# y=labels_csv[['final_labels']].to_numpy()

# skf = StratifiedKFold(n_splits=2)
# skf.get_n_splits(X, y)

# for Gtrain_index, Gtest_index in skf.split(X, y):
#     GX_train, GX_test = X[Gtrain_index], X[Gtest_index]
# Gy_train, Gy_test = y[Gtrain_index], y[Gtest_index]

# imgs_path='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/ISIC-2017_Training_Part1_GroundTruth/'
# for idx in range(len(GX_train)):
#     img=GX_train[idx][0]
#     im=imgs_path+img+'_segmentation.png'
#     print(im)
#     shutil.copy(im,'D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/GT_train')

# pathFolder_train='D:/Respaldo/Documents/MAIA/UNICAS/AImageP/project/FILES/Dataset/GT_train/' 
# filesArray = [x for x in os.listdir(pathFolder_train) if os.path.isfile(os.path.join(pathFolder_train,x))]
